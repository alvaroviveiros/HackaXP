# %%
import pandas as pd
import json
import os

# %%
from glob2 import glob

jsonFiles = glob('data/00-50/*.json')
print(jsonFiles)
# Out:
# ['data/00-50\\page00.json', 'data/00-50\\page01.json', 'data/00-50\\page02.json', 'data/00-50\\page03.json', 'data/00-50\\page04.json', 'data/00-50\\page05.json', 'data/00-50\\page06.json', 'data/00-50\\page07.json', 'data/00-50\\page08.json', 'data/00-50\\page09.json', 'data/00-50\\page10.json', 'data/00-50\\page100.json', 'data/00-50\\page101.json', 'data/00-50\\page102.json', 'data/00-50\\page103.json', 'data/00-50\\page104.json', 'data/00-50\\page105.json', 'data/00-50\\page106.json', 'data/00-50\\page107.json', 'data/00-50\\page108.json', 'data/00-50\\page109.json', 'data/00-50\\page11.json', 'data/00-50\\page110.json', 'data/00-50\\page111.json', 'data/00-50\\page112.json', 'data/00-50\\page113.json', 'data/00-50\\page114.json', 'data/00-50\\page115.json', 'data/00-50\\page116.json', 'data/00-50\\page117.json', 'data/00-50\\page118.json', 'data/00-50\\page119.json', 'data/00-50\\page12.json', 'data/00-50\\page120.json', 'data/00-50\\page121.json', 'data/00-50\\page122.json', 'd
# ...

# %%
from flatten_json import flatten 

dfList = []

for jsonFile in jsonFiles:
    f = open(jsonFile)
    user = json.load(f)

    df = pd.DataFrame([flatten(x) for x in user])
    dfList.append(df)
    
dfTrainingDF = pd.concat(dfList, axis=0)

# %%
df = dfTrainingDF 
df
# Out:
#          name          cpf    salary    bornDate  banks_0_suitability  \
# 0        JOSE  99999999990  14156.55  1993-10-16                   27
# 1        JOAO  99999999991   5087.48  2001-04-14                   78
# 2     ANTONIO  99999999992  37402.39  1957-05-11                   55
# 3   FRANCISCO  99999999993  29486.15  1959-09-28                   47
# 4      CARLOS  99999999994  21993.62  1988-02-22                   22
# ..        ...          ...       ...         ...                  ...
# 5     ADRIANA  99999910004  18300.58  1995-01-08                   46
# 6     JULIANA  99999910005  30867.57  1949-10-28                   12
# 7      MARCIA  99999910006  12785.19  1988-07-08                   22
# 8    FERNANDA  99999910007  35740.56  1969-01-22                   10
# 9    PATRICIA  99999910008   9021.93  1965-01-22                   98
#
#    banks_0_startDate banks_0_institution_agency banks_0_institution_number  \
# ...

# %%
df_infos = df[['name', 'cpf', 'salary', 'bornDate']]

# %%
df_infos
# Out:
#          name          cpf    salary    bornDate
# 0        JOSE  99999999990  14156.55  1993-10-16
# 1        JOAO  99999999991   5087.48  2001-04-14
# 2     ANTONIO  99999999992  37402.39  1957-05-11
# 3   FRANCISCO  99999999993  29486.15  1959-09-28
# 4      CARLOS  99999999994  21993.62  1988-02-22
# ..        ...          ...       ...         ...
# 5     ADRIANA  99999910004  18300.58  1995-01-08
# 6     JULIANA  99999910005  30867.57  1949-10-28
# 7      MARCIA  99999910006  12785.19  1988-07-08
# 8    FERNANDA  99999910007  35740.56  1969-01-22
# 9    PATRICIA  99999910008   9021.93  1965-01-22
#
# [1955 rows x 4 columns]

# %%
df_suitability = df[['banks_0_suitability',
                     'banks_1_suitability',
                     'banks_2_suitability',
                     'banks_3_suitability',]]

# %%
df_suitability
# Out:
#     banks_0_suitability  banks_1_suitability  banks_2_suitability  \
# 0                    27                    8                    4
# 1                    78                   46                   21
# 2                    55                   58                   98
# 3                    47                    6                   30
# 4                    22                   20                   82
# ..                  ...                  ...                  ...
# 5                    46                   64                   31
# 6                    12                   23                   15
# 7                    22                   73                   71
# 8                    10                   72                   54
# 9                    98                   16                   42
#
#     banks_3_suitability
# 0                    73
# 1                    74
# 2                    77
# 3                    91
# 4                    38
# ...

# %%
df_credit = df[[
                'banks_0_creditCard_limit', 'banks_0_creditCard_revolvingCredit', 'banks_0_creditCard_revolvingCreditTax', 'banks_0_creditCard_installmentsUsage',
                'banks_1_creditCard_limit', 'banks_1_creditCard_revolvingCredit', 'banks_1_creditCard_revolvingCreditTax', 'banks_1_creditCard_installmentsUsage',
                'banks_2_creditCard_limit', 'banks_2_creditCard_revolvingCredit', 'banks_2_creditCard_revolvingCreditTax', 'banks_2_creditCard_installmentsUsage',
                'banks_3_creditCard_limit', 'banks_3_creditCard_revolvingCredit', 'banks_3_creditCard_revolvingCreditTax', 'banks_3_creditCard_installmentsUsage',]]

# %%
df_credit
# Out:
#     banks_0_creditCard_limit  banks_0_creditCard_revolvingCredit  \
# 0                   18936.76                             3170.00
# 1                   17749.63                            26794.44
# 2                   12362.14                             8700.06
# 3                    5088.27                            12056.71
# 4                    1079.85                            12593.90
# ..                       ...                                 ...
# 5                   21394.20                             2144.29
# 6                    8739.70                            22788.56
# 7                   24638.53                            22012.42
# 8                   29565.11                             1745.48
# 9                   11196.45                            27580.95
#
#     banks_0_creditCard_revolvingCreditTax  \
# 0                                0.076537
# 1                                0.055231
# 2                                0.031011
# ...

# %%
df_savings = df[[
                 'banks_0_saving_balance',
                 'banks_1_saving_balance',
                 'banks_2_saving_balance',
                 'banks_3_saving_balance',]]

# %%
df_savings
# Out:
#     banks_0_saving_balance  banks_1_saving_balance  banks_2_saving_balance  \
# 0                        0                       0                 1629454
# 1                        0                       0                  775788
# 2                        0                       0                       0
# 3                   411693                       0                 2501405
# 4                  1498482                       0                 2986233
# ..                     ...                     ...                     ...
# 5                        0                       0                  304051
# 6                        0                  422317                       0
# 7                  1328351                       0                       0
# 8                        0                 2590866                       0
# 9                        0                 1483618                       0
#
#     banks_3_saving_balance
# 0                  2747833
# ...

# %%
df_pix_0 = df[['banks_0_pixHistory_0_value', 
               'banks_0_pixHistory_1_value',
               'banks_0_pixHistory_2_value',
               'banks_0_pixHistory_3_value',
               'banks_0_pixHistory_4_value',
               'banks_0_pixHistory_5_value',
               'banks_0_pixHistory_6_value',
               'banks_0_pixHistory_7_value',
               'banks_0_pixHistory_8_value',
               'banks_0_pixHistory_9_value']]

df['banks_0_pix_volume'] = df_pix_0.sum(axis=1)

df_pix_1 = df[['banks_1_pixHistory_0_value', 
               'banks_1_pixHistory_1_value',
               'banks_1_pixHistory_2_value',
               'banks_1_pixHistory_3_value',
               'banks_1_pixHistory_4_value',
               'banks_1_pixHistory_5_value',
               'banks_1_pixHistory_6_value',
               'banks_1_pixHistory_7_value',
               'banks_1_pixHistory_8_value',
               'banks_1_pixHistory_9_value']]

df['banks_1_pix_volume'] = df_pix_1.sum(axis=1)

df_pix_2 = df[['banks_2_pixHistory_0_value', 
               'banks_2_pixHistory_1_value',
               'banks_2_pixHistory_2_value',
               'banks_2_pixHistory_3_value',
               'banks_2_pixHistory_4_value',
               'banks_2_pixHistory_5_value',
               'banks_2_pixHistory_6_value',
               'banks_2_pixHistory_7_value',
               'banks_2_pixHistory_8_value',
               'banks_2_pixHistory_9_value']]

df['banks_2_pix_volume'] = df_pix_2.sum(axis=1)

df_pix_3 = df[['banks_3_pixHistory_0_value', 
               'banks_3_pixHistory_1_value',
               'banks_3_pixHistory_2_value',
               'banks_3_pixHistory_3_value',
               'banks_3_pixHistory_4_value',
               'banks_3_pixHistory_5_value',
               'banks_3_pixHistory_6_value',
               'banks_3_pixHistory_7_value',
               'banks_3_pixHistory_8_value',
               'banks_3_pixHistory_9_value']]

df['banks_3_pix_volume'] = df_pix_3.sum(axis=1)

# %%
df_pix = df[[
             'banks_0_pix_volume', 'banks_1_pix_volume', 'banks_2_pix_volume','banks_3_pix_volume']]

# %%
df_pix
# Out:
#     banks_0_pix_volume  banks_1_pix_volume  banks_2_pix_volume  \
# 0            597657.25           528224.43           619350.86
# 1            363973.39           547951.79           558851.77
# 2            503961.19           435122.01           687595.30
# 3            391737.62           512708.33           513257.90
# 4            524346.85           500632.11           607713.84
# ..                 ...                 ...                 ...
# 5            385978.67           385893.87           585015.14
# 6            297791.13           516260.30           385063.48
# 7            622439.64           584298.54           684094.53
# 8            462443.33           439526.04           369704.07
# 9            518040.63           555089.64           533048.46
#
#     banks_3_pix_volume
# 0            485338.28
# 1            531797.88
# 2            547721.87
# 3            252417.95
# 4            482697.51
# ..                 ...
# 5            497168.79
# ...

# %%
df_lines = df[[
               'banks_0_consumedCreditLines_0_type', 'banks_0_consumedCreditLines_0_tax', 'banks_0_consumedCreditLines_0_installments',
               'banks_1_consumedCreditLines_0_type', 'banks_1_consumedCreditLines_0_tax', 'banks_1_consumedCreditLines_0_installments',
               'banks_2_consumedCreditLines_0_type', 'banks_2_consumedCreditLines_0_tax', 'banks_2_consumedCreditLines_0_installments',
               'banks_3_consumedCreditLines_0_type', 'banks_3_consumedCreditLines_0_tax', 'banks_3_consumedCreditLines_0_installments']]

# %%
df_lines
# Out:
#    banks_0_consumedCreditLines_0_type  banks_0_consumedCreditLines_0_tax  \
# 0                             leasing                           0.432114
# 1                       personal-loan                           0.697097
# 2                       personal-loan                           0.625389
# 3                             leasing                           0.054133
# 4                             leasing                           0.346786
# ..                                ...                                ...
# 5                             leasing                           0.219908
# 6                       personal-loan                           0.631160
# 7                       personal-loan                           0.057862
# 8                       personal-loan                           0.658566
# 9                             leasing                           0.545414
#
#     banks_0_consumedCreditLines_0_installments  \
# ...

# %%
df_stocks_0_vol = df[['banks_0_investments_stocks_0_volumn', 'banks_0_investments_stocks_1_volumn', 'banks_0_investments_stocks_2_volumn', 'banks_0_investments_stocks_3_volumn']]
df_stocks_0_val = df[['banks_0_investments_stocks_0_value', 'banks_0_investments_stocks_1_value', 'banks_0_investments_stocks_2_value', 'banks_0_investments_stocks_3_value']]

df_stocks = pd.DataFrame()

df_stocks['df_stocks_0_total_bank0'] = df_stocks_0_vol['banks_0_investments_stocks_0_volumn']*df_stocks_0_val['banks_0_investments_stocks_0_value']
df_stocks['df_stocks_1_total_bank0'] = df_stocks_0_vol['banks_0_investments_stocks_1_volumn']*df_stocks_0_val['banks_0_investments_stocks_1_value']
df_stocks['df_stocks_2_total_bank0'] = df_stocks_0_vol['banks_0_investments_stocks_2_volumn']*df_stocks_0_val['banks_0_investments_stocks_2_value']
df_stocks['df_stocks_3_total_bank0'] = df_stocks_0_vol['banks_0_investments_stocks_3_volumn']*df_stocks_0_val['banks_0_investments_stocks_3_value']

df['banks_0_stocks_volume'] = df_stocks.sum(axis=1)

df_stocks_1_vol = df[['banks_1_investments_stocks_0_volumn', 'banks_1_investments_stocks_1_volumn', 'banks_1_investments_stocks_2_volumn', 'banks_1_investments_stocks_3_volumn']]
df_stocks_1_val = df[['banks_1_investments_stocks_0_value', 'banks_1_investments_stocks_1_value', 'banks_1_investments_stocks_2_value', 'banks_1_investments_stocks_3_value']]

df_stocks['df_stocks_0_total_bank1'] = df_stocks_1_vol['banks_1_investments_stocks_0_volumn']*df_stocks_1_val['banks_1_investments_stocks_0_value']
df_stocks['df_stocks_1_total_bank1'] = df_stocks_1_vol['banks_1_investments_stocks_1_volumn']*df_stocks_1_val['banks_1_investments_stocks_1_value']
df_stocks['df_stocks_2_total_bank1'] = df_stocks_1_vol['banks_1_investments_stocks_2_volumn']*df_stocks_1_val['banks_1_investments_stocks_2_value']
df_stocks['df_stocks_3_total_bank1'] = df_stocks_1_vol['banks_1_investments_stocks_3_volumn']*df_stocks_1_val['banks_1_investments_stocks_3_value']

df['banks_1_stocks_volume'] = df_stocks.sum(axis=1)

df_stocks_2_vol = df[['banks_2_investments_stocks_0_volumn', 'banks_2_investments_stocks_1_volumn', 'banks_2_investments_stocks_2_volumn', 'banks_2_investments_stocks_3_volumn']]
df_stocks_2_val = df[['banks_2_investments_stocks_0_value', 'banks_2_investments_stocks_1_value', 'banks_2_investments_stocks_2_value', 'banks_2_investments_stocks_3_value']]

df_stocks['df_stocks_0_total_bank2'] = df_stocks_2_vol['banks_2_investments_stocks_0_volumn']*df_stocks_2_val['banks_2_investments_stocks_0_value']
df_stocks['df_stocks_1_total_bank2'] = df_stocks_2_vol['banks_2_investments_stocks_1_volumn']*df_stocks_2_val['banks_2_investments_stocks_1_value']
df_stocks['df_stocks_2_total_bank2'] = df_stocks_2_vol['banks_2_investments_stocks_2_volumn']*df_stocks_2_val['banks_2_investments_stocks_2_value']
df_stocks['df_stocks_3_total_bank2'] = df_stocks_2_vol['banks_2_investments_stocks_3_volumn']*df_stocks_2_val['banks_2_investments_stocks_3_value']

df['banks_2_stocks_volume'] = df_stocks.sum(axis=1)

df_stocks_3_vol = df[['banks_3_investments_stocks_0_volumn', 'banks_3_investments_stocks_1_volumn', 'banks_3_investments_stocks_2_volumn', 'banks_3_investments_stocks_3_volumn']]
df_stocks_3_val = df[['banks_3_investments_stocks_0_value', 'banks_3_investments_stocks_1_value', 'banks_3_investments_stocks_2_value', 'banks_3_investments_stocks_3_value']]

df_stocks['df_stocks_0_total_bank2'] = df_stocks_3_vol['banks_3_investments_stocks_0_volumn']*df_stocks_3_val['banks_3_investments_stocks_0_value']
df_stocks['df_stocks_1_total_bank2'] = df_stocks_3_vol['banks_3_investments_stocks_1_volumn']*df_stocks_3_val['banks_3_investments_stocks_1_value']
df_stocks['df_stocks_2_total_bank2'] = df_stocks_3_vol['banks_3_investments_stocks_2_volumn']*df_stocks_3_val['banks_3_investments_stocks_2_value']
df_stocks['df_stocks_3_total_bank2'] = df_stocks_3_vol['banks_3_investments_stocks_3_volumn']*df_stocks_3_val['banks_3_investments_stocks_3_value']

df['banks_3_stocks_volume'] = df_stocks.sum(axis=1)

# %%
df_stocks_final = df[['banks_0_stocks_volume', 'banks_1_stocks_volume', 'banks_2_stocks_volume','banks_3_stocks_volume']]

# %%
df_stocks_final
# Out:
#     banks_0_stocks_volume  banks_1_stocks_volume  banks_2_stocks_volume  \
# 0                  902816                1840768                3160305
# 1                  847479                2028985                2690246
# 2                  797500                1560536                2042604
# 3                 1470359                2459673                4094993
# 4                 1104848                1625381                2725231
# ..                    ...                    ...                    ...
# 5                 1360709                3231699                3810281
# 6                 1485673                3700800                4432373
# 7                 1018395                2346399                3870369
# 8                  458941                 827701                1373250
# 9                  763176                1920425                3586956
#
#     banks_3_stocks_volume
# 0                 2850637
# 1                 3786698
# ...

# %%
df_fundos = pd.DataFrame()

df_fundos_0_val = df[['banks_0_investments_investmentFunds_0_value', 'banks_0_investments_investmentFunds_1_value', 'banks_0_investments_investmentFunds_2_value', 'banks_0_investments_investmentFunds_3_value']]
df_fundos_0_vol = df[['banks_0_investments_investmentFunds_0_volumn', 'banks_0_investments_investmentFunds_1_volumn', 'banks_0_investments_investmentFunds_2_volumn', 'banks_0_investments_investmentFunds_3_volumn']]

df_fundos['df_fundos_0_total_bank0'] = df_fundos_0_val['banks_0_investments_investmentFunds_0_value']*df_fundos_0_vol['banks_0_investments_investmentFunds_0_volumn']
df_fundos['df_fundos_1_total_bank0'] = df_fundos_0_val['banks_0_investments_investmentFunds_1_value']*df_fundos_0_vol['banks_0_investments_investmentFunds_1_volumn']
df_fundos['df_fundos_2_total_bank0'] = df_fundos_0_val['banks_0_investments_investmentFunds_2_value']*df_fundos_0_vol['banks_0_investments_investmentFunds_2_volumn']
df_fundos['df_fundos_3_total_bank0'] = df_fundos_0_val['banks_0_investments_investmentFunds_3_value']*df_fundos_0_vol['banks_0_investments_investmentFunds_3_volumn']

df['banks_0_fundos_volume'] = df_fundos.sum(axis=1)

df_fundos_0_val = df[['banks_1_investments_investmentFunds_0_value', 'banks_1_investments_investmentFunds_1_value', 'banks_1_investments_investmentFunds_2_value', 'banks_1_investments_investmentFunds_3_value']]
df_fundos_0_vol = df[['banks_1_investments_investmentFunds_0_volumn', 'banks_1_investments_investmentFunds_1_volumn', 'banks_1_investments_investmentFunds_2_volumn', 'banks_1_investments_investmentFunds_3_volumn']]

df_fundos['df_fundos_0_total_bank1'] = df_fundos_0_val['banks_1_investments_investmentFunds_0_value']*df_fundos_0_vol['banks_1_investments_investmentFunds_0_volumn']
df_fundos['df_fundos_1_total_bank1'] = df_fundos_0_val['banks_1_investments_investmentFunds_1_value']*df_fundos_0_vol['banks_1_investments_investmentFunds_1_volumn']
df_fundos['df_fundos_2_total_bank1'] = df_fundos_0_val['banks_1_investments_investmentFunds_2_value']*df_fundos_0_vol['banks_1_investments_investmentFunds_2_volumn']
df_fundos['df_fundos_3_total_bank1'] = df_fundos_0_val['banks_1_investments_investmentFunds_3_value']*df_fundos_0_vol['banks_1_investments_investmentFunds_3_volumn']

df['banks_1_fundos_volume'] = df_fundos.sum(axis=1)

df_fundos_0_val = df[['banks_2_investments_investmentFunds_0_value', 'banks_2_investments_investmentFunds_1_value', 'banks_2_investments_investmentFunds_2_value', 'banks_2_investments_investmentFunds_3_value']]
df_fundos_0_vol = df[['banks_2_investments_investmentFunds_0_volumn', 'banks_2_investments_investmentFunds_1_volumn', 'banks_2_investments_investmentFunds_2_volumn', 'banks_2_investments_investmentFunds_3_volumn']]

df_fundos['df_fundos_0_total_bank2'] = df_fundos_0_val['banks_2_investments_investmentFunds_0_value']*df_fundos_0_vol['banks_2_investments_investmentFunds_0_volumn']
df_fundos['df_fundos_1_total_bank2'] = df_fundos_0_val['banks_2_investments_investmentFunds_1_value']*df_fundos_0_vol['banks_2_investments_investmentFunds_1_volumn']
df_fundos['df_fundos_2_total_bank2'] = df_fundos_0_val['banks_2_investments_investmentFunds_2_value']*df_fundos_0_vol['banks_2_investments_investmentFunds_2_volumn']
df_fundos['df_fundos_3_total_bank2'] = df_fundos_0_val['banks_2_investments_investmentFunds_3_value']*df_fundos_0_vol['banks_2_investments_investmentFunds_3_volumn']

df['banks_2_fundos_volume'] = df_fundos.sum(axis=1)

df_fundos_0_val = df[['banks_3_investments_investmentFunds_0_value', 'banks_3_investments_investmentFunds_1_value', 'banks_3_investments_investmentFunds_2_value', 'banks_3_investments_investmentFunds_3_value']]
df_fundos_0_vol = df[['banks_3_investments_investmentFunds_0_volumn', 'banks_3_investments_investmentFunds_1_volumn', 'banks_3_investments_investmentFunds_2_volumn', 'banks_3_investments_investmentFunds_3_volumn']]

df_fundos['df_fundos_0_total_bank3'] = df_fundos_0_val['banks_3_investments_investmentFunds_0_value']*df_fundos_0_vol['banks_3_investments_investmentFunds_0_volumn']
df_fundos['df_fundos_1_total_bank3'] = df_fundos_0_val['banks_3_investments_investmentFunds_1_value']*df_fundos_0_vol['banks_3_investments_investmentFunds_1_volumn']
df_fundos['df_fundos_2_total_bank3'] = df_fundos_0_val['banks_3_investments_investmentFunds_2_value']*df_fundos_0_vol['banks_3_investments_investmentFunds_2_volumn']
df_fundos['df_fundos_3_total_bank3'] = df_fundos_0_val['banks_3_investments_investmentFunds_3_value']*df_fundos_0_vol['banks_3_investments_investmentFunds_3_volumn']

df['banks_3_fundos_volume'] = df_fundos.sum(axis=1)

# %%
df_fundos_final = df[['banks_0_fundos_volume', 'banks_1_fundos_volume', 'banks_2_fundos_volume','banks_3_fundos_volume']]

# %%
df_fundos_final
# Out:
#     banks_0_fundos_volume  banks_1_fundos_volume  banks_2_fundos_volume  \
# 0                 1439037                4637670                5705326
# 1                  921824                2786392                4504878
# 2                 2336590                4009424                6931627
# 3                  506489                2580986                4560772
# 4                 1693940                4298609                6917668
# ..                    ...                    ...                    ...
# 5                 2566152                3021042                5117182
# 6                  930711                2623616                4325937
# 7                 1647554                3716490                5027688
# 8                 1760847                4064790                6955594
# 9                 1723562                4605985                6960122
#
#     banks_3_fundos_volume
# 0                 6107081
# 1                 5344946
# ...

# %%
df_final = pd.concat([df_infos, df_suitability, df_credit, df_savings, df_pix, df_lines, df_stocks_final, df_fundos_final], axis=1)
df_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1955 entries, 0 to 9
# Data columns (total 52 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   name                                        1955 non-null   object
#  1   cpf                                         1955 non-null   object
#  2   salary                                      1955 non-null   float64
#  3   bornDate                                    1955 non-null   object
#  4   banks_0_suitability                         1955 non-null   int64
#  5   banks_1_suitability                         1955 non-null   int64
#  6   banks_2_suitability                         1955 non-null   int64
#  7   banks_3_suitability                         1955 non-null   int64
#  8   banks_0_creditCard_limit                    1955 non-null   float64
#  9   banks_0_creditCard_revolvingCredit          1955 non-null   float64
# ...

# %%
df_bank_0 = pd.concat([df_infos, df_final.loc[:,df_final.columns.str.startswith('banks_0')]], axis=1)
df_bank_1 = pd.concat([df_infos, df_final.loc[:,df_final.columns.str.startswith('banks_1')]], axis=1)
df_bank_2 = pd.concat([df_infos, df_final.loc[:,df_final.columns.str.startswith('banks_2')]], axis=1)
df_bank_3 = pd.concat([df_infos, df_final.loc[:,df_final.columns.str.startswith('banks_3')]], axis=1)

# %%
df_bank_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1955 entries, 0 to 9
# Data columns (total 16 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   name                                        1955 non-null   object
#  1   cpf                                         1955 non-null   object
#  2   salary                                      1955 non-null   float64
#  3   bornDate                                    1955 non-null   object
#  4   banks_0_suitability                         1955 non-null   int64
#  5   banks_0_creditCard_limit                    1955 non-null   float64
#  6   banks_0_creditCard_revolvingCredit          1955 non-null   float64
#  7   banks_0_creditCard_revolvingCreditTax       1955 non-null   float64
#  8   banks_0_creditCard_installmentsUsage        1955 non-null   bool
#  9   banks_0_saving_balance                      1955 non-null   int64
# ...

# %% [markdown]
# Banco 0

# %%
corr0 = df_bank_0.corr()
corr0.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_d1e2c_row0_col0, #T_d1e2c_row1_col1, #T_d1e2c_row2_col2, #T_d1e2c_row3_col3, #T_d1e2c_row4_col4, #T_d1e2c_row5_col5, #T_d1e2c_row6_col6, #T_d1e2c_row7_col7, #T_d1e2c_row8_col8, #T_d1e2c_row9_col9, #T_d1e2c_row10_col10, #T_d1e2c_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_d1e2c_row0_col1, #T_d1e2c_row0_col5, #T_d1e2c_row1_col0, #T_d1e2c_row2_col7, #T_d1e2c_row2_col9, #T_d1e2c_row4_col11, #T_d1e2c_row7_col2, #T_d1e2c_row8_col10, #T_d1e2c_row9_col6, #T_d1e2c_row10_col8, #T_d1e2c_row11_col2, #T_d1e2c_row11_col3, #T_d1e2c_row11_col4, #T_d1e2c_row11_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_d1e2c_row0_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_d1e2c_row0_col3, #T_d1e2c_row1_col2, #T_d1e2c_row2_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_d1e2c_row0_col4, #T_d1e2c_row0_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# ...

# %%
df_bank_0.corr().unstack().sort_values().drop_duplicates()
# Out:
# banks_0_suitability       salary                                  -0.147257
# banks_0_fundos_volume     banks_0_creditCard_revolvingCreditTax   -0.125780
# banks_0_stocks_volume     banks_0_consumedCreditLines_0_tax       -0.116826
# salary                    banks_0_creditCard_installmentsUsage    -0.115277
# banks_0_creditCard_limit  banks_0_pix_volume                      -0.101963
#                                                                      ...
# banks_0_pix_volume        banks_0_creditCard_revolvingCreditTax    0.087499
# banks_0_saving_balance    banks_0_creditCard_revolvingCredit       0.094551
#                           banks_0_creditCard_revolvingCreditTax    0.099976
# banks_0_fundos_volume     salary                                   0.116480
# salary                    salary                                   1.000000
# Length: 67, dtype: float64

# %% [markdown]
# Banco 1

# %%
corr1 = df_bank_1.corr()
corr1.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1da16_row0_col0, #T_1da16_row1_col1, #T_1da16_row2_col2, #T_1da16_row3_col3, #T_1da16_row4_col4, #T_1da16_row5_col5, #T_1da16_row6_col6, #T_1da16_row7_col7, #T_1da16_row8_col8, #T_1da16_row9_col9, #T_1da16_row10_col10, #T_1da16_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1da16_row0_col1, #T_1da16_row8_col10, #T_1da16_row9_col7, #T_1da16_row11_col5 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_1da16_row0_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_1da16_row0_col3, #T_1da16_row3_col5, #T_1da16_row3_col8, #T_1da16_row9_col6 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_1da16_row0_col4, #T_1da16_row5_col6, #T_1da16_row6_col4, #T_1da16_row10_col2 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_1da16_row0_col5, #T_1da16_row4_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# ...

# %%
df_bank_1.corr().unstack().sort_values().drop_duplicates()
# Out:
# banks_1_fundos_volume                       banks_1_saving_balance                       -0.194627
# banks_1_creditCard_revolvingCreditTax       banks_1_pix_volume                           -0.155081
# banks_1_consumedCreditLines_0_installments  banks_1_saving_balance                       -0.134225
# banks_1_suitability                         banks_1_saving_balance                       -0.112213
# banks_1_creditCard_revolvingCreditTax       banks_1_consumedCreditLines_0_installments   -0.101928
#                                                                                             ...
# banks_1_consumedCreditLines_0_tax           salary                                        0.122995
# banks_1_pix_volume                          banks_1_consumedCreditLines_0_tax             0.124379
# salary                                      banks_1_stocks_volume                         0.126714
# ...

# %% [markdown]
# Banco 2

# %%
corr2 = df_bank_2.corr()
corr2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_32c4e_row0_col0, #T_32c4e_row1_col1, #T_32c4e_row2_col2, #T_32c4e_row3_col3, #T_32c4e_row4_col4, #T_32c4e_row5_col5, #T_32c4e_row6_col6, #T_32c4e_row7_col7, #T_32c4e_row8_col8, #T_32c4e_row9_col9, #T_32c4e_row10_col10, #T_32c4e_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_32c4e_row0_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_32c4e_row0_col2, #T_32c4e_row2_col0, #T_32c4e_row2_col7, #T_32c4e_row3_col1, #T_32c4e_row3_col4, #T_32c4e_row3_col8, #T_32c4e_row4_col3, #T_32c4e_row4_col6, #T_32c4e_row4_col10, #T_32c4e_row5_col11, #T_32c4e_row8_col9, #T_32c4e_row9_col2, #T_32c4e_row11_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_32c4e_row0_col3, #T_32c4e_row0_col4, #T_32c4e_row0_col11, #T_32c4e_row6_col8 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_32c4e_row0_col5, #T_32c4e_row3_col7, #T_32c4e_row6_col7, #T_32c4e_row10_col5 {
#   background-color: #5572df;
# ...

# %%
df_bank_2.corr().unstack().sort_values().drop_duplicates()
# Out:
# banks_2_creditCard_revolvingCreditTax  banks_2_creditCard_revolvingCredit      -0.189292
# banks_2_consumedCreditLines_0_tax      banks_2_creditCard_revolvingCredit      -0.168630
# banks_2_creditCard_installmentsUsage   banks_2_fundos_volume                   -0.132203
# banks_2_creditCard_revolvingCreditTax  banks_2_saving_balance                  -0.117722
#                                        banks_2_stocks_volume                   -0.107119
#                                                                                   ...
# banks_2_pix_volume                     banks_2_creditCard_installmentsUsage     0.102946
# salary                                 banks_2_fundos_volume                    0.109576
# banks_2_creditCard_limit               banks_2_creditCard_revolvingCreditTax    0.138475
# banks_2_creditCard_installmentsUsage   banks_2_suitability                      0.148207
# salary                                 salary                                   1.000000
# ...

# %% [markdown]
# Banco 3

# %%
corr3 = df_bank_3.corr()
corr3.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_30bc2_row0_col0, #T_30bc2_row1_col1, #T_30bc2_row2_col2, #T_30bc2_row3_col3, #T_30bc2_row4_col4, #T_30bc2_row5_col5, #T_30bc2_row6_col6, #T_30bc2_row7_col7, #T_30bc2_row8_col8, #T_30bc2_row9_col9, #T_30bc2_row10_col10, #T_30bc2_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_30bc2_row0_col1, #T_30bc2_row0_col9, #T_30bc2_row7_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_30bc2_row0_col2, #T_30bc2_row5_col4, #T_30bc2_row6_col8, #T_30bc2_row8_col10, #T_30bc2_row9_col7, #T_30bc2_row11_col5 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_30bc2_row0_col3, #T_30bc2_row0_col5, #T_30bc2_row7_col4, #T_30bc2_row8_col1, #T_30bc2_row10_col7 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_30bc2_row0_col4, #T_30bc2_row8_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# ...

# %%
df_bank_3.corr().unstack().sort_values().drop_duplicates()
# Out:
# banks_3_pix_volume                          banks_3_fundos_volume                        -0.189349
# banks_3_consumedCreditLines_0_tax           banks_3_creditCard_revolvingCreditTax        -0.124749
# banks_3_pix_volume                          banks_3_saving_balance                       -0.111293
# banks_3_consumedCreditLines_0_installments  banks_3_saving_balance                       -0.110155
# banks_3_creditCard_revolvingCredit          banks_3_saving_balance                       -0.087556
#                                                                                             ...
# banks_3_stocks_volume                       salary                                        0.141944
# banks_3_fundos_volume                       banks_3_saving_balance                        0.152558
# banks_3_stocks_volume                       banks_3_consumedCreditLines_0_installments    0.156361
# ...

# %% [markdown]
# ## features mais correlacionadas
# ### banco 0
# banks_0_pix_volume        banks_0_creditCard_revolvingCreditTax    0.087499
# banks_0_saving_balance    banks_0_creditCard_revolvingCredit       0.094551
#                           banks_0_creditCard_revolvingCreditTax    0.099976
# banks_0_fundos_volume     salary                                   0.116480
#
# ### banco 1
# bbanks_1_consumedCreditLines_0_tax           salary                                        0.122995
# banks_1_pix_volume                          banks_1_consumedCreditLines_0_tax             0.124379
# salary                                      banks_1_stocks_volume                         0.126714
# banks_1_creditCard_installmentsUsage        banks_1_consumedCreditLines_0_installments    0.146597
#
# ### banco 2
# banks_2_pix_volume                     banks_2_creditCard_installmentsUsage     0.102946
# salary                                 banks_2_fundos_volume                    0.109576
# banks_2_creditCard_limit               banks_2_creditCard_revolvingCreditTax    0.138475
# banks_2_creditCard_installmentsUsage   banks_2_suitability                      0.148207
#
# ### banco 3
# banks_3_stocks_volume                       salary                                        0.141944
# banks_3_fundos_volume                       banks_3_saving_balance                        0.152558
# banks_3_stocks_volume                       banks_3_consumedCreditLines_0_installments    0.156361
# banks_3_consumedCreditLines_0_tax           banks_3_creditCard_installmentsUsage          0.176001

# %%
from pycaret.classification import *

s = setup(df_bank_0, target = 'banks_0_fundos_volume')
# Out:
# <style type="text/css">
# #T_e9b14_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e9b14_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e9b14_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e9b14_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_e9b14_row0_col1" class="data row0 col1" >1471</td>
#     </tr>
#     <tr>
#       <th id="T_e9b14_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e9b14_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e9b14_row1_col1" class="data row1 col1" >banks_0_fundos_volume</td>
#     </tr>
#     <tr>
#       <th id="T_e9b14_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
stop
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17396/3957423419.py in <module>
# ----> 1 stop
#
# NameError: name 'stop' is not defined

# %%
best_model = compare_models(sort='AUC')
print(best_model)
# Out:
# IntProgress(value=0, description='Processing: ', max=79)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                      23:14:52
# Status     . . . . . . . . . . . . . . . . . .              Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Gradient Boosting Classifier
# <style type="text/css">
# #T_6d3d9_ th {
#   text-align: left;
# }
# ...

# %%
xgboost = create_model('xgboost')
# Out:
# IntProgress(value=0, description='Processing: ', max=4)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   23:48:46
# Status     . . . . . . . . . . . . . . . . . .           Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Extreme Gradient Boosting
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17396/3164726954.py in <module>
# ----> 1 xgboost = create_model('xgboost')
#
# ~\AppData\Roaming\Python\Python37\site-packages\pycaret\classification.py in create_model(estimator, fold, round, cross_validation, fit_kwargs, groups, verbose, **kwargs)
#     896         groups=groups,
#     897         verbose=verbose,
# --> 898         **kwargs,
#     899     )
#     900
#
# ...
